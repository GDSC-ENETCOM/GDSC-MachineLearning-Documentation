# %%
# Import necessary libaries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# [Click for correction]
# <!--
# data = pd.read_csv('/content/Student_Performance_Data.csv')
# -->

# %%
# Load Student Performance Data to the variable 'data'
data =

# %% [markdown]
# [Click for correction]
# <!--
# data.shape
# -->

# %%
# Print data shape
# Out:
# (395, 20)

# %% [markdown]
# [Click for correction]
# <!--
# data.head()
# -->

# %%
# Print head of the data (first 5 lines)
# Out:
#   sex  age famsize  Medu  Fedu     Mjob      Fjob  traveltime  studytime  \
# 0   F   18     GT3     4     4  at_home   teacher           2          2
# 1   F   17     GT3     1     1  at_home     other           1          2
# 2   F   15     LE3     1     1  at_home     other           1          2
# 3   F   15     GT3     4     2   health  services           1          3
# 4   F   16     GT3     3     3    other     other           1          2
#
#    failures schoolsup famsup activities higher internet romantic  freetime  \
# 0         0       yes     no         no    yes       no       no         3
# 1         0        no    yes         no    yes      yes       no         3
# 2         3       yes     no         no    yes      yes       no         3
# 3         0        no    yes        yes    yes      yes      yes         2
# 4         0        no    yes         no    yes       no       no         3
#
#    health  absences      Approval
# 0       3         6  not_approved
# ...

# %% [markdown]
# [Click for correction]
# <!--
# data.info()
# -->

# %%
# Print data informations
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         395 non-null    object
#  1   age         395 non-null    int64
#  2   famsize     395 non-null    object
#  3   Medu        395 non-null    int64
#  4   Fedu        395 non-null    int64
#  5   Mjob        395 non-null    object
#  6   Fjob        395 non-null    object
#  7   traveltime  395 non-null    int64
#  8   studytime   395 non-null    int64
#  9   failures    395 non-null    int64
#  10  schoolsup   395 non-null    object
#  11  famsup      395 non-null    object
#  12  activities  395 non-null    object
#  13  higher      395 non-null    object
#  14  internet    395 non-null    object
#  15  romantic    395 non-null    object
#  16  freetime    395 non-null    int64
#  17  health      395 non-null    int64
#  18  absences    395 non-null    int64
# ...

# %% [markdown]
# Comment: the data has no missing values

# %% [markdown]
# [Click for correction]
# <!--
# data.dtypes.value_counts().plot.pie()
# -->

# %%
# Print the piechart for visualizing categorical and numerical columns
# Out:
# <Axes: >

# %% [markdown]
# [Click for correction]
# <!--
# data.describe()
# -->

# %%
# Show the description of data for visualizing the mean, std, median.. of each column
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#          freetime      health    absences
# count  395.000000  395.000000  395.000000
# mean     3.235443    3.554430    5.708861
# std      0.998862    1.390303    8.003096
# min      1.000000    1.000000    0.000000
# 25%      3.000000    3.000000    0.000000
# ...

# %% [markdown]
# [Click for correction]
# <!--
# correlation = data.corr()
# correlation
# -->

# %%
# Print the correlation matrix
# Out:
# <ipython-input-73-d0c05ed7dfe2>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation = data.corr()
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %% [markdown]
# Make interpretations:

# %% [markdown]
# [Click for correction]
# <!--
# plt.figure(figsize=(20,10))
# sns.heatmap(correlation,annot=True)
# -->

# %%
# Showing the heatmap for the correlation matrix
plt.figure(figsize=(20,10)) # for making the size of the figure bigger
# Out:
# <Axes: >

# %% [markdown]
# Make the interpretation:

# %% [markdown]
# [Click for correction]
# <!--
# categorical_data=[]
# numerical_data=[]
# for i,c in enumerate(data.dtypes):
#     if c=='object':
#         categorical_data.append(data.iloc[:,i])
#     else:
#         numerical_data.append(data.iloc[:,i])
# -->

# %%
# Splitting the data to categorical and numerical data
categorical_data = []
numerical_data = []
for i,c in enumerate(data.dtypes):
    if c=='object':
    else:

# %%
categorical_data = pd.DataFrame(categorical_data).transpose()
numerical_data = pd.DataFrame(numerical_data).transpose()

# %%
categorical_data
# Out:
#     sex famsize      Mjob      Fjob schoolsup famsup activities higher  \
# 0     F     GT3   at_home   teacher       yes     no         no    yes
# 1     F     GT3   at_home     other        no    yes         no    yes
# 2     F     LE3   at_home     other       yes     no         no    yes
# 3     F     GT3    health  services        no    yes        yes    yes
# 4     F     GT3     other     other        no    yes         no    yes
# ..   ..     ...       ...       ...       ...    ...        ...    ...
# 390   M     LE3  services  services        no    yes         no    yes
# 391   M     LE3  services  services        no     no         no    yes
# 392   M     GT3     other     other        no     no         no    yes
# 393   M     LE3  services     other        no     no         no    yes
# 394   M     LE3     other   at_home        no     no         no    yes
#
#     internet romantic      Approval
# 0         no       no  not_approved
# 1        yes       no  not_approved
# ...

# %%
numerical_data
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  freetime  health  \
# 0     18     4     4           2          2         0         3       3
# 1     17     1     1           1          2         0         3       3
# 2     15     1     1           1          2         3         3       3
# 3     15     4     2           1          3         0         2       5
# 4     16     3     3           1          2         0         3       5
# ..   ...   ...   ...         ...        ...       ...       ...     ...
# 390   20     2     2           1          2         2         5       4
# 391   17     3     1           2          1         0         4       2
# 392   21     1     1           1          1         3         5       3
# 393   18     3     2           3          1         0         4       5
# 394   19     1     1           1          1         0         2       5
#
#      absences
# 0           6
# 1           4
# 2          10
# 3           2
# 4           4
# ...

# %% [markdown]
# [Click for correction]
# <!--
# categorical_data.nunique()
# -->

# %%
# Print the data unique values number
# Out:
# sex           2
# famsize       2
# Mjob          5
# Fjob          5
# schoolsup     2
# famsup        2
# activities    2
# higher        2
# internet      2
# romantic      2
# Approval      2
# dtype: int64

# %% [markdown]
# [Click for correction]
# <!--
# for col in categorical_data:
#     categorical_data[col].hist()
#     plt.title(col)
#     plt.show()
# -->

# %%
#Print the categorical data histogram

# %%
# data
for col in numerical_data:
    fig, ax = plt.subplots(figsize = (13,5))
 .....
